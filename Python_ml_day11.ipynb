# %%
import pandas as pd

# %%
house_data = pd.read_csv('melb_data.csv')

# %%
house_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
house_data2 = pd.read_csv('melb_data.csv', index_col=2)

# %%
house_data2.head()
# Out:
#            Suburb           Address Type      Price Method SellerG       Date  \
# Rooms
# 2      Abbotsford      85 Turner St    h  1480000.0      S  Biggin  3/12/2016
# 2      Abbotsford   25 Bloomburg St    h  1035000.0      S  Biggin  4/02/2016
# 3      Abbotsford      5 Charles St    h  1465000.0     SP  Biggin  4/03/2017
# 3      Abbotsford  40 Federation La    h   850000.0     PI  Biggin  4/03/2017
# 4      Abbotsford       55a Park St    h  1600000.0     VB  Nelson  4/06/2016
#
#        Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# Rooms
# 2           2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 2           2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 3           2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3           2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4           2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
# ...

# %%
house_data.SellerG
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
house_data['SellerG']
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
house_data['SellerG'][2]
# Out:
# 'Biggin'

# %% [markdown]
# ## Accessor operators in Pandas--- .loc(), iloc()

# %%
# .iloc -- based on indexing position --- 0,1,2---rows first, column second
## 0 row , all columns
print(house_data.iloc[0])
# Out:
# Suburb                      Abbotsford
# Address                   85 Turner St
# Rooms                                2
# Type                                 h
# Price                         1.48e+06
# Method                               S
# SellerG                         Biggin
# Date                         3/12/2016
# Distance                           2.5
# Postcode                          3067
# Bedroom2                             2
# Bathroom                             1
# Car                                  1
# Landsize                           202
# BuildingArea                       NaN
# YearBuilt                          NaN
# CouncilArea                      Yarra
# Lattitude                     -37.7996
# Longtitude                     144.998
# Regionname       Northern Metropolitan
# Propertycount                     4019
# Name: 0, dtype: object

# %%
## all row, 0 columns
house_data.iloc[:, 0]
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
## range.. first 3 rows in 0 col
house_data.iloc[:3, 0]
# Out:
# 0    Abbotsford
# 1    Abbotsford
# 2    Abbotsford
# Name: Suburb, dtype: object

# %%
## can also pass as a list
house_data.iloc[[1,2,3],0]
# Out:
# 1    Abbotsford
# 2    Abbotsford
# 3    Abbotsford
# Name: Suburb, dtype: object

# %%
## negative indexing
house_data.iloc[-5:]
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
### .loc() -- label based selection
house_data.loc[0, 'Suburb']
# Out:
# 'Abbotsford'

# %%
## more than one column
print(house_data.loc[:5, ['Suburb', 'Address', 'Method', 'Date']])
# Out:
#        Suburb           Address Method       Date
# 0  Abbotsford      85 Turner St      S  3/12/2016
# 1  Abbotsford   25 Bloomburg St      S  4/02/2016
# 2  Abbotsford      5 Charles St     SP  4/03/2017
# 3  Abbotsford  40 Federation La     PI  4/03/2017
# 4  Abbotsford       55a Park St     VB  4/06/2016
# 5  Abbotsford    129 Charles St      S  7/05/2016

# %% [markdown]
# ### diff. bw .loc and .iloc in indexing - in .loc - 0:10.. 10 is inclusive, also works with strings // in .iloc.. 0:10 10 is exclusive

# %% [markdown]
# ## Manipulating the index-- using .set_index

# %%
house_data.set_index('Address')
# Out:
#                          Suburb  Rooms Type      Price Method   SellerG  \
# Address
# 85 Turner St         Abbotsford      2    h  1480000.0      S    Biggin
# 25 Bloomburg St      Abbotsford      2    h  1035000.0      S    Biggin
# 5 Charles St         Abbotsford      3    h  1465000.0     SP    Biggin
# 40 Federation La     Abbotsford      3    h   850000.0     PI    Biggin
# 55a Park St          Abbotsford      4    h  1600000.0     VB    Nelson
# ...                         ...    ...  ...        ...    ...       ...
# 12 Strada Cr      Wheelers Hill      4    h  1245000.0      S     Barry
# 77 Merrett Dr      Williamstown      3    h  1031000.0     SP  Williams
# 83 Power St        Williamstown      3    h  1170000.0      S     Raine
# 96 Verdon St       Williamstown      4    h  2500000.0     PI   Sweeney
# 6 Agnes St           Yarraville      4    h  1285000.0     SP   Village
#
#                         Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Address
# ...

# %% [markdown]
# ## Conditional Selection

# %%
## checking house in Suburb -- Abbotsford
house_data.Suburb == 'Abbotsford'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: Suburb, Length: 13580, dtype: bool

# %%
## getting all data of Suburb -- Abbotsford
house_data.loc[house_data.Suburb == 'Abbotsford']
# Out:
#            Suburb              Address  Rooms Type      Price Method  \
# 0      Abbotsford         85 Turner St      2    h  1480000.0      S
# 1      Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 2      Abbotsford         5 Charles St      3    h  1465000.0     SP
# 3      Abbotsford     40 Federation La      3    h   850000.0     PI
# 4      Abbotsford          55a Park St      4    h  1600000.0     VB
# 5      Abbotsford       129 Charles St      2    h   941000.0      S
# 6      Abbotsford         124 Yarra St      3    h  1876000.0      S
# 7      Abbotsford        98 Charles St      2    h  1636000.0      S
# 8      Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 9      Abbotsford        10 Valiant St      2    h  1097000.0      S
# 10     Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 11     Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 12     Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# ...

# %%
## can use two conditions on data with ampersand &..suburb == 'Abbotsford' and Type == 'h'
house_data.loc[(house_data.Suburb == 'Abbotsford') & (house_data.Type == 'h')]
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 0      Abbotsford      85 Turner St      2    h  1480000.0      S
# 1      Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2      Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3      Abbotsford  40 Federation La      3    h   850000.0     PI
# 4      Abbotsford       55a Park St      4    h  1600000.0     VB
# 5      Abbotsford    129 Charles St      2    h   941000.0      S
# 6      Abbotsford      124 Yarra St      3    h  1876000.0      S
# 7      Abbotsford     98 Charles St      2    h  1636000.0      S
# 9      Abbotsford     10 Valiant St      2    h  1097000.0      S
# 11     Abbotsford   40 Nicholson St      3    h  1350000.0     VB
# 13     Abbotsford     45 William St      2    h  1172500.0      S
# 15     Abbotsford     16 William St      2    h  1310000.0      S
# 16     Abbotsford       42 Henry St      3    h  1200000.0      S
# ...

# %%
## | Pipe .. as an OR cond. in Pandas.. house in Abbotsford Suburb or price less than 1230000
house_data.loc[(house_data.Suburb== 'Abbotsford') | (house_data.Price <= 1230000)]
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 0        Abbotsford      85 Turner St      2    h  1480000.0      S
# 1        Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford  40 Federation La      3    h   850000.0     PI
# 4        Abbotsford       55a Park St      4    h  1600000.0     VB
# ...             ...               ...    ...  ...        ...    ...
# 13572      Watsonia     76 Kenmare St      2    h   650000.0     PI
# 13573      Werribee       5 Nuragi Ct      4    h   635000.0      S
# 13574   Westmeadows        9 Black St      3    h   582000.0      S
# 13576  Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  Williamstown       83 Power St      3    h  1170000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# ## .isin

# %%
## .isin -- isin is lets you select data whose value "is in" a list of value

# %%
house_data.loc[house_data.Suburb.isin(['Abbotsford', 'Williamstown'])]
# Out:
#              Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0        Abbotsford      85 Turner St      2    h  1480000.0      S    Biggin
# 1        Abbotsford   25 Bloomburg St      2    h  1035000.0      S    Biggin
# 2        Abbotsford      5 Charles St      3    h  1465000.0     SP    Biggin
# 3        Abbotsford  40 Federation La      3    h   850000.0     PI    Biggin
# 4        Abbotsford       55a Park St      4    h  1600000.0     VB    Nelson
# ...             ...               ...    ...  ...        ...    ...       ...
# 13084  Williamstown    54 Victoria St      5    h  2550000.0     PI  Williams
# 13329  Williamstown   146 Ferguson St      3    h   832000.0      S  Williams
# 13576  Williamstown     77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577  Williamstown       83 Power St      3    h  1170000.0      S     Raine
# 13578  Williamstown      96 Verdon St      4    h  2500000.0     PI   Sweeney
#
# ...

# %% [markdown]
# ## isnull -- for checking null values or data....notnull -- opposite of isnull..These methods let you highlight values which are (or are not) empty (NaN).

# %%
house_data.loc[house_data.Landsize.isnull()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Assigning Data to a Dataframe

# %%
## adding a new column -- Name with a constant value
house_data['Name'] = 'Sachin'
house_data['Name']
# Out:
# 0        Sachin
# 1        Sachin
# 2        Sachin
# 3        Sachin
# 4        Sachin
#           ...
# 13575    Sachin
# 13576    Sachin
# 13577    Sachin
# 13578    Sachin
# 13579    Sachin
# Name: Name, Length: 13580, dtype: object

# %%
house_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
house_data['index_back'] = range(len(house_data), 0, -1)
house_data['index_back']
# Out:
# 0        13580
# 1        13579
# 2        13578
# 3        13577
# 4        13576
#          ...
# 13575        5
# 13576        4
# 13577        3
# 13578        2
# 13579        1
# Name: index_back, Length: 13580, dtype: int64

# %%
house_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...
